# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from img2vec import gray2emb
import math
import os
import pandas as pd
import joblib

# Define the batch size
batch_size = 256

# %% [markdown]
# ### read the data

# %%
train_data = pd.read_csv(os.path.join('..', '..', 'data', 'train.csv'))
val_data = pd.read_csv(os.path.join('..', '..', 'data', 'val.csv'))
test_data = pd.read_csv(os.path.join('..', '..', 'data', 'test.csv'))

# %% [markdown]
# ### add the path of the images

# %%
def construct_img_path(row):
    return os.path.join("..", "..", "data", "faces", row['user_id'],
                        "coarse_tilt_aligned_face." + str(row['face_id']) + "." + row['original_image'])


train_data['img_path'] = train_data.apply(construct_img_path, axis=1)
val_data['img_path'] = val_data.apply(construct_img_path, axis=1)
test_data['img_path'] = test_data.apply(construct_img_path, axis=1)
train_data.head(5)
# Out:
#          user_id  face_id                original_image        age gender  \
# 0    9855553@N08     1581  11658657103_4485e3f5ac_o.jpg  (60, 100)      m
# 1  114841417@N06      502  12059583524_606ca96139_o.jpg   (15, 20)      m
# 2   66870968@N06     1227  11326189206_e08bdf6dfd_o.jpg   (25, 32)      m
# 3    8187011@N06      988  11133041085_e2ee5e12cb_o.jpg     (0, 2)      u
# 4  114841417@N06      485  12059753735_7141b5443c_o.jpg   (15, 20)      f
#
#                                             img_path
# 0  ..\..\data\faces\9855553@N08\coarse_tilt_align...
# 1  ..\..\data\faces\114841417@N06\coarse_tilt_ali...
# 2  ..\..\data\faces\66870968@N06\coarse_tilt_alig...
# 3  ..\..\data\faces\8187011@N06\coarse_tilt_align...
# 4  ..\..\data\faces\114841417@N06\coarse_tilt_ali...

# %% [markdown]
# #### add column for check if the image exists
# it will help us to detect if there is any missing image, or if there is any bug in the path construction

# %%
train_data['img_exists'] = train_data['img_path'].apply(os.path.exists)
val_data['img_exists'] = val_data['img_path'].apply(os.path.exists)
test_data['img_exists'] = test_data['img_path'].apply(os.path.exists)

train_data.head(5)
# Out:
#          user_id  face_id                original_image        age gender  \
# 0    9855553@N08     1581  11658657103_4485e3f5ac_o.jpg  (60, 100)      m
# 1  114841417@N06      502  12059583524_606ca96139_o.jpg   (15, 20)      m
# 2   66870968@N06     1227  11326189206_e08bdf6dfd_o.jpg   (25, 32)      m
# 3    8187011@N06      988  11133041085_e2ee5e12cb_o.jpg     (0, 2)      u
# 4  114841417@N06      485  12059753735_7141b5443c_o.jpg   (15, 20)      f
#
#                                             img_path  img_exists
# 0  ..\..\data\faces\9855553@N08\coarse_tilt_align...        True
# 1  ..\..\data\faces\114841417@N06\coarse_tilt_ali...        True
# 2  ..\..\data\faces\66870968@N06\coarse_tilt_alig...        True
# 3  ..\..\data\faces\8187011@N06\coarse_tilt_align...        True
# 4  ..\..\data\faces\114841417@N06\coarse_tilt_ali...        True

# %%
# Encode age labels
age_encoder = LabelEncoder()
train_data['age_label'] = age_encoder.fit_transform(train_data['age'])
val_data['age_label'] = age_encoder.transform(val_data['age'])
test_data['age_label'] = age_encoder.transform(test_data['age'])
num_classes = len(age_encoder.classes_)
print("Age classes:", age_encoder.classes_)
train_data.head(5)
# Out:
# Age classes: ['(0, 2)' '(15, 20)' '(25, 32)' '(38, 43)' '(4, 6)' '(48, 53)' '(60, 100)'
#  '(8, 23)']
#          user_id  face_id                original_image        age gender  \
# 0    9855553@N08     1581  11658657103_4485e3f5ac_o.jpg  (60, 100)      m
# 1  114841417@N06      502  12059583524_606ca96139_o.jpg   (15, 20)      m
# 2   66870968@N06     1227  11326189206_e08bdf6dfd_o.jpg   (25, 32)      m
# 3    8187011@N06      988  11133041085_e2ee5e12cb_o.jpg     (0, 2)      u
# 4  114841417@N06      485  12059753735_7141b5443c_o.jpg   (15, 20)      f
#
#                                             img_path  img_exists  age_label
# 0  ..\..\data\faces\9855553@N08\coarse_tilt_align...        True          6
# 1  ..\..\data\faces\114841417@N06\coarse_tilt_ali...        True          1
# 2  ..\..\data\faces\66870968@N06\coarse_tilt_alig...        True          2
# 3  ..\..\data\faces\8187011@N06\coarse_tilt_align...        True          0
# 4  ..\..\data\faces\114841417@N06\coarse_tilt_ali...        True          1

# %% [markdown]
# ### Filter out any rows where the image doesn't exist

# %%
train_data_filtered = train_data[train_data['img_exists'] == True]
val_data_filtered = val_data[val_data['img_exists'] == True]
test_data_filtered = test_data[test_data['img_exists'] == True]

# %% [markdown]
# ### Define a generator function to process images in batches

# %%
def image_batch_generator(image_paths, labels, batch_size):
    num_samples = len(image_paths)
    num_batches = math.ceil(num_samples / batch_size)

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, num_samples)

        batch_paths = image_paths[start_idx:end_idx]
        batch_features = gray2emb(batch_paths) / 255.0  # Normalize to [0,1]
        batch_labels = labels[start_idx:end_idx]

        yield batch_features, batch_labels

# %% [markdown]
# ### Extract image paths and labels

# %%
train_image_paths = train_data_filtered['img_path'].tolist()
train_labels = train_data_filtered['age_label'].values

val_image_paths = val_data_filtered['img_path'].tolist()
val_labels = val_data_filtered['age_label'].values

test_image_paths = test_data_filtered['img_path'].tolist()
test_labels = test_data_filtered['age_label'].values

# %% [markdown]
# ### Process a single batch to determine input shape

# %%
print("Processing a sample batch to determine input dimensions...")
sample_batch_size = min(10, len(train_image_paths))
sample_paths = train_image_paths[:sample_batch_size]
sample_batch = gray2emb(sample_paths)
input_shape = sample_batch.shape[1]
print(f"Input shape: {input_shape}")
# Out:
# Processing a sample batch to determine input dimensions...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Input shape: 2048

# %% [markdown]
# ### Define the model

# %%
model = Sequential([
    Dense(num_classes, activation='softmax', input_shape=(input_shape,))
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# C:\Users\shayg\projects\ML\final_project\venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │        16,392 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,392 (64.03 KB)
#  Trainable params: 16,392 (64.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model using batches

# %%
print("Training the model...")
epochs = 100
steps_per_epoch = math.ceil(len(train_image_paths) / batch_size)
validation_steps = math.ceil(len(val_image_paths) / batch_size)

# Custom training loop
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    # Training
    train_loss = 0
    train_acc = 0
    batch_count = 0

    for batch_features, batch_labels in image_batch_generator(train_image_paths, train_labels, batch_size):
        # Train on batch
        batch_history = model.train_on_batch(
            batch_features,
            batch_labels,
        )

        batch_loss, batch_acc = batch_history
        train_loss += batch_loss
        train_acc += batch_acc
        batch_count += 1

        print(f"\rBatch {batch_count}/{steps_per_epoch} - loss: {batch_loss:.4f} - accuracy: {batch_acc:.4f}", end="")

    avg_train_loss = train_loss / batch_count
    avg_train_acc = train_acc / batch_count
    train_losses.append(avg_train_loss)
    train_accuracies.append(avg_train_acc)

    # Validation
    val_loss = 0
    val_acc = 0
    batch_count = 0

    for batch_features, batch_labels in image_batch_generator(val_image_paths, val_labels, batch_size):
        # Evaluate on batch
        batch_val_loss, batch_val_acc = model.test_on_batch(
            batch_features,
            batch_labels,
        )

        val_loss += batch_val_loss
        val_acc += batch_val_acc
        batch_count += 1

    avg_val_loss = val_loss / batch_count
    avg_val_acc = val_acc / batch_count
    val_losses.append(avg_val_loss)
    val_accuracies.append(avg_val_acc)

    print(
        f"\nEpoch {epoch + 1}: loss={avg_train_loss:.4f}, accuracy={avg_train_acc:.4f}, val_loss={avg_val_loss:.4f}, val_accuracy={avg_val_acc:.4f}")
# Out:
# Training the model...
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 494ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 489ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 438ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 462ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 427ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 632ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 543ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 601ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 498ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 627ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 663ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 566ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 571ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 572ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 605ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 553ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 500ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 532ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 598ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 562ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 607ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 500ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 445ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 511ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 540ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 612ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 595ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 613ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 594ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 777ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 773ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 739ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 762ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 721ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 560ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 636ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 570ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 521ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 587ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 537ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 525ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 546ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 565ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 571ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 519ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 552ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 563ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 829ms/step
#
# Epoch 1: loss=2.0487, accuracy=0.2975, val_loss=2.0164, val_accuracy=0.2994
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 551ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 496ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 513ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 857ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 639ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 584ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 535ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 573ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 643ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 519ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 568ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 642ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 641ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 632ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 741ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 658ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 639ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 724ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 641ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 639ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 645ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 719ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 643ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 635ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 724ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 641ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 648ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 736ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 647ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 651ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 651ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 658ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 654ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 740ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 647ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 646ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 655ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 777ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 665ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 647ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 666ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 663ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 694ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 886ms/step
#
# Epoch 2: loss=1.9947, accuracy=0.2978, val_loss=1.9742, val_accuracy=0.2965
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 658ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 644ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 669ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 674ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 642ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 797ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 781ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 653ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 746ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 661ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 726ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 645ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 650ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 747ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 631ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 638ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 645ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 650ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 657ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 644ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 644ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 670ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 650ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 658ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 752ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 654ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 767ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 650ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 737ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 653ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 710ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 785ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 650ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 660ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 737ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 666ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 733ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 869ms/step
#
# Epoch 3: loss=1.9577, accuracy=0.2962, val_loss=1.9426, val_accuracy=0.2962
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 724ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 757ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 663ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 716ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 660ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 769ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 660ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 787ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 655ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 651ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 786ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 659ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 751ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 660ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 658ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 735ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 792ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 658ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 666ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 807ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 725ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 734ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 643ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 760ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 717ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 660ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 667ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 738ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 660ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 659ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 731ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 651ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 643ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 788ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 869ms/step
#
# Epoch 4: loss=1.9297, accuracy=0.2968, val_loss=1.9178, val_accuracy=0.2979
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 663ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 855ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 826ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 666ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 717ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 666ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 822ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 734ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 706ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 780ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 661ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 666ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 767ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 728ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 669ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 767ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 658ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 663ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 667ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 666ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 759ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 725ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 771ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 720ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 815ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 878ms/step
#
# Epoch 5: loss=1.9072, accuracy=0.3004, val_loss=1.8972, val_accuracy=0.3033
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 797ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 729ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 665ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 769ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 751ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 659ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 844ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 702ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 814ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 669ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 746ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 726ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 776ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 860ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 667ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 667ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 738ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 726ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 830ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 719ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 896ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 682ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 929ms/step
#
# Epoch 6: loss=1.8880, accuracy=0.3071, val_loss=1.8794, val_accuracy=0.3110
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 761ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 667ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 665ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 766ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 752ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 667ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 799ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 778ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 669ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 733ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 674ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 670ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 857ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 753ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 720ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 801ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 663ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 746ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 731ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 807ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 669ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 853ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 7: loss=1.8711, accuracy=0.3153, val_loss=1.8634, val_accuracy=0.3193
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 733ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 841ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 759ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 786ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 665ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 670ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 829ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 755ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 814ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 722ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 861ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 670ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 742ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 771ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 852ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 670ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 867ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 836ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 709ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 722ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 793ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 883ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 891ms/step
#
# Epoch 8: loss=1.8559, accuracy=0.3235, val_loss=1.8488, val_accuracy=0.3273
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 680ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 739ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 760ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 873ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 861ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 761ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 735ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 841ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 676ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 680ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 848ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 667ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 749ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 789ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 766ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 742ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 856ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 739ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 772ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 710ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 720ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 806ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 842ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 683ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 883ms/step
#
# Epoch 9: loss=1.8418, accuracy=0.3312, val_loss=1.8352, val_accuracy=0.3345
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 743ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 762ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 726ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 740ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 674ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 675ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 842ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 751ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 787ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 870ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 834ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 814ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 741ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 835ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 727ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 727ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 803ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 872ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 762ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 749ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 929ms/step
#
# Epoch 10: loss=1.8287, accuracy=0.3380, val_loss=1.8226, val_accuracy=0.3410
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 738ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 834ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 851ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 752ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 767ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 829ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 850ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 680ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 829ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 735ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 803ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 886ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 680ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 797ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 715ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 826ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 875ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 772ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 781ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 881ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 897ms/step
#
# Epoch 11: loss=1.8165, accuracy=0.3441, val_loss=1.8107, val_accuracy=0.3466
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 862ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 680ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 735ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 869ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 780ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 781ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 761ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 840ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 857ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 842ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 723ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 855ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 860ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 710ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 746ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 778ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 896ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 728ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 699ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 680ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 719ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 812ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 721ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 855ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 702ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 829ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 886ms/step
#
# Epoch 12: loss=1.8049, accuracy=0.3493, val_loss=1.7994, val_accuracy=0.3516
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 751ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 838ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 840ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 710ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 744ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 770ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 875ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 734ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 706ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 716ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 835ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 749ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 797ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 682ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 860ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 803ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 732ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 781ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 13: loss=1.7939, accuracy=0.3540, val_loss=1.7887, val_accuracy=0.3560
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 688ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 678ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 745ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 725ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 710ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 742ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 763ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 731ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 743ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 737ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 834ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 848ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 756ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 716ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 684ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 720ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 672ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 882ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 729ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 673ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 734ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 905ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 883ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 671ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 647ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 740ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 686ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 648ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 717ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 681ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 664ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 642ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 743ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 677ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 925ms/step
#
# Epoch 14: loss=1.7834, accuracy=0.3582, val_loss=1.7785, val_accuracy=0.3600
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 792ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 668ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 770ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 650ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 716ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 639ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 649ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 756ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 670ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 679ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 650ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 734ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 654ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 723ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 830ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 769ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 702ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 748ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 782ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 716ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 780ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 754ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 759ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 838ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 754ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 752ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 735ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 732ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 768ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 729ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 775ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 784ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 838ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 798ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 899ms/step
#
# Epoch 15: loss=1.7734, accuracy=0.3620, val_loss=1.7687, val_accuracy=0.3636
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 706ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 754ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 772ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 685ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 844ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 777ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 731ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 720ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 804ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 737ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 706ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 729ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 727ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 781ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 710ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 773ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 717ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 840ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 831ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 739ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 737ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 844ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 687ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 814ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 755ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 717ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 723ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 834ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 709ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 815ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 690ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 720ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 762ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 818ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 905ms/step
#
# Epoch 16: loss=1.7639, accuracy=0.3654, val_loss=1.7593, val_accuracy=0.3669
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 848ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 763ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 850ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 780ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 855ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 798ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 747ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 716ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 831ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 731ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 779ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 725ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 765ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 786ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 737ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 727ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 794ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 823ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 700ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 802ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 725ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 728ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 828ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 17: loss=1.7547, accuracy=0.3685, val_loss=1.7504, val_accuracy=0.3700
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 732ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 727ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 801ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 733ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 733ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 789ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 730ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 832ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 691ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 710ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 767ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 722ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 729ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 729ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 831ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 741ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 694ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 836ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 706ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 758ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 815ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 844ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 686ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 830ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 898ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 702ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 774ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 995ms/step
#
# Epoch 18: loss=1.7459, accuracy=0.3714, val_loss=1.7418, val_accuracy=0.3728
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 801ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 695ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 732ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 743ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 838ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 702ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 832ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 748ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 757ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 843ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 886ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 797ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 709ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 876ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 803ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 734ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 725ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 737ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 847ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 832ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 692ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 759ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 730ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 702ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 702ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 760ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 963ms/step
#
# Epoch 19: loss=1.7375, accuracy=0.3742, val_loss=1.7335, val_accuracy=0.3754
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 803ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 732ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 891ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 726ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 841ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 749ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 719ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 887ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 716ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 746ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 717ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 835ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 732ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 736ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 735ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 708ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 763ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 747ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 700ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 890ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 796ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 706ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 782ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 696ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 739ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 885ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 718ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 787ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 724ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 768ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 709ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 711ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 704ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 796ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 705ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 792ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 912ms/step
#
# Epoch 20: loss=1.7294, accuracy=0.3768, val_loss=1.7255, val_accuracy=0.3780
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 879ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 712ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step
# ...
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 833ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 906ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 883ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 835ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 954ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 857ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 830ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 959ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 862ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 823ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 927ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 807ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 930ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 871ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 806ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 967ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 814ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 842ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 840ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 807ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 949ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 909ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 969ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 940ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 94: loss=1.4571, accuracy=0.4587, val_loss=1.4562, val_accuracy=0.4590
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 972ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 952ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 812ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 902ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 887ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 829ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 939ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 809ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 871ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 848ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 987ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 859ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 884ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 953ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 812ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 815ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 902ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 809ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 902ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 815ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 994ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 859ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 806ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 975ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 918ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 804ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 874ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 831ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 858ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 864ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 820ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 868ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 826ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 969ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 801ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 875ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 795ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 931ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 815ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 832ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
#
# Epoch 95: loss=1.4553, accuracy=0.4593, val_loss=1.4544, val_accuracy=0.4596
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 798ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 894ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 945ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 812ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 937ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 852ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 929ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 882ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 909ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 807ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 965ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 794ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 841ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 831ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 981ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 867ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 920ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 815ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 924ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 809ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 996ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 804ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 838ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 812ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 968ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 814ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 814ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 940ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 884ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 972ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 801ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 871ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 819ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 96: loss=1.4534, accuracy=0.4599, val_loss=1.4526, val_accuracy=0.4601
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 980ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 821ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 907ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 911ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 831ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 966ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 822ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 809ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 802ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 973ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 802ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 806ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 836ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 960ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 810ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 961ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 956ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 828ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 916ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 828ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 920ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 877ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 812ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 823ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 859ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 821ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 874ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 895ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 802ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 983ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 922ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 940ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 793ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 979ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 97: loss=1.4517, accuracy=0.4605, val_loss=1.4508, val_accuracy=0.4607
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 853ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 802ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 901ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 812ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 834ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 913ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 797ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 947ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 803ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 966ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 828ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 912ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 844ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 814ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 932ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 930ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 819ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 811ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 972ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 815ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 910ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 808ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 824ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 999ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 809ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 873ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 931ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 790ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 932ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 801ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 957ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 899ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 803ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 919ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 817ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 896ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 98: loss=1.4499, accuracy=0.4610, val_loss=1.4490, val_accuracy=0.4613
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 820ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 966ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 881ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 889ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 784ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 853ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 779ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 778ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 933ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 773ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 798ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 859ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 861ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 764ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 871ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 786ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 833ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 770ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 769ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 832ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 800ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 857ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 779ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 920ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 780ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 785ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 787ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 879ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 777ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 790ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 882ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 776ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 826ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 780ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 780ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 893ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 779ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 804ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 831ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 809ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 784ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 779ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 916ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 774ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 786ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 795ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 845ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 777ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 771ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 99: loss=1.4481, accuracy=0.4616, val_loss=1.4473, val_accuracy=0.4618
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 773ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 779ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 916ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 778ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 782ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 791ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 937ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 806ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 816ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 893ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 841ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 895ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 825ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 826ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 916ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 888ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 834ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 974ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 833ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 948ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 841ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 993ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 925ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 866ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 881ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 826ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 902ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 990ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 818ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 858ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 852ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 913ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 846ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 861ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 856ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 999ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 840ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 954ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 845ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
#
# Epoch 100: loss=1.4464, accuracy=0.4621, val_loss=1.4456, val_accuracy=0.4624

# %% [markdown]
# ### Evaluate the model on test data

# %%
print("Evaluating the model on test data...")
test_loss = 0
test_acc = 0
batch_count = 0
all_predictions = []
all_labels = []

for batch_features, batch_labels in image_batch_generator(test_image_paths, test_labels, batch_size):
    # Evaluate on batch
    batch_test_loss, batch_test_acc = model.test_on_batch(
        batch_features,
        batch_labels,
    )

    # Get predictions for this batch
    batch_preds = model.predict_on_batch(batch_features)
    batch_pred_classes = np.argmax(batch_preds, axis=1)

    all_predictions.extend(batch_pred_classes)
    all_labels.extend(batch_labels)

    test_loss += batch_test_loss
    test_acc += batch_test_acc
    batch_count += 1

avg_test_loss = test_loss / batch_count
avg_test_acc = test_acc / batch_count
print(f"Test Loss: {avg_test_loss:.4f}")
print(f"Test Accuracy: {avg_test_acc:.4f}")
# Out:
# Evaluating the model on test data...
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 773ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 904ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 769ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 889ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 787ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 946ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 759ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 776ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 828ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 942ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 767ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
# Test Loss: 1.4454
# Test Accuracy: 0.4624

# %% [markdown]
# ### Visualize results

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')

plt.tight_layout()
plt.savefig('training_history.png')
plt.show()

# Confusion matrix
plt.figure(figsize=(10, 8))
cm = confusion_matrix(all_labels, all_predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=age_encoder.classes_,
            yticklabels=age_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig('confusion_matrix.png')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(all_labels, all_predictions, target_names=age_encoder.classes_))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       (0, 2)       0.65      0.84      0.73       483
#     (15, 20)       0.15      0.05      0.08       227
#     (25, 32)       0.40      0.89      0.55      1036
#     (38, 43)       0.30      0.10      0.15       543
#       (4, 6)       0.63      0.30      0.41       570
#     (48, 53)       0.00      0.00      0.00       258
#    (60, 100)       0.78      0.08      0.14       274
#      (8, 23)       0.26      0.19      0.22       340
#
#     accuracy                           0.44      3731
#    macro avg       0.40      0.31      0.29      3731
# weighted avg       0.43      0.44      0.37      3731

# %% [markdown]
# ### Save the model and LabelEncoder

# %%
model.save('basic_softmax_age_classifier.h5')
print("Model saved successfully.")

# Save the LabelEncoder
joblib.dump(age_encoder, 'age_encoder.pkl')
print("Age encoder saved successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully.
# Age encoder saved successfully.

# %% [markdown]
# ### exapmle of use

# %%
import joblib
import numpy as np
import tensorflow as tf
from img2vec import gray2emb

# Load the trained model
model = tf.keras.models.load_model('basic_softmax_age_classifier.h5')
print("Model loaded successfully.")

# Load the LabelEncoder
age_encoder = joblib.load('age_encoder.pkl')
print("Age encoder loaded successfully.")


# Function to predict age range for a new image
def predict_age(image_path, model, age_encoder):
    # Extract features using gray2emb
    features = gray2emb([image_path])
    # Normalize features
    features = features / 255.0
    # Make prediction
    pred_probs = model.predict(features)[0]
    # Get predicted class
    pred_class = np.argmax(pred_probs)
    # Convert to age range
    pred_age_range = age_encoder.classes_[pred_class]
    confidence = pred_probs[pred_class]

    return pred_age_range, confidence

# Example usage:
image_path = "img.jpg"
pred_age, confidence = predict_age(image_path, model, age_encoder)
print(f"Predicted age range: {pred_age} with confidence {confidence:.2f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully.
# Age encoder loaded successfully.
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DFD15116C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DFD15116C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# WARNING:tensorflow:6 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DFD1510940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DFD1510940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Predicted age range: (38, 43) with confidence 0.34
